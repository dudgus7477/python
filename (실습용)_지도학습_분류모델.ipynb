# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/python/blob/main/(%EC%8B%A4%EC%8A%B5%EC%9A%A9)_%EC%A7%80%EB%8F%84%ED%95%99%EC%8A%B5_%EB%B6%84%EB%A5%98%EB%AA%A8%EB%8D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #분류모델
# >분류 모델은 출력을 두 가지의 클래스(0,1)로 구분하는 이진 분류 모델과
# 그 이상의 클래스로 구분하는 다중 분류 모델로 나누어 볼 수 있다.
# ##### - 출력을 연속적인 값이 아니라 두 개로 구분하는 데이터셋을 가장 잘 설명할 수 있는 것은 직선이 아니라 0,1을 극단적으로 지나는 곡선이다.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 시그모이드 함수를 활용한 이진 분류 모델 -> 로지스틱 회귀 모델
# 로지스틱 회귀 모델에서도 핵심은 H(X)의 비용을 최적화하는 W와 b값을 찾는 것이다.
#
# ###![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 10명의 데이터 셋(시험점수, 합격 여부)
# #### 입력 변수(x)는 시험 점수 하나이며, 출력은 합격(1), 불합격(0)의 두 클래스로

# %%
# 데이터 생성
import numpy as np

x = np.array([[74],[81],[94],[68],[64],[70],[83],[94],[71],[74]]) # 시험점수
y = np.array([1,1,1,0,0,0,1,1,0,1])

# %% [markdown]
# #모델 만들기

# %%
#예측하기

# %% [markdown]
# #실습하기1
# > 타이타닉호에서 생존할 수 있는지 예측해보자!
# ###### - SibSp : 동반한 형제자매와 배우자의 수
# ###### - Parch : 동반한 부모와 자식의 수
# ###### - Cabin : 객실번호
# ###### - Embarked : 승선한 항
