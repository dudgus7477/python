# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/python/blob/main/(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%ED%8C%8C%EC%9D%B4%EC%8D%AC_1%EC%9D%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 파이썬 명령어 형식
# ![캡처.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # 2. 출력명령어
# ### 출력 명령어 형식
#
# > print(출력할 내용)

# %%
# 숫자 출력 2023

# %%
# 문자 출력 3월 29일

# %% [markdown]
# ### 문자는 따옴표로 감싸주어야 함
# > print('문자')

# %%
#연산자

# %%
#숫자라 하더라도 따옴표로 감싸면 문자로 인식

# %%
# ** 제곱


#몫


#나머지

# %% [markdown]
# ### 연결하여 출력하기
# >print( , )
# <br/>
# >print( + )

# %%
#콤마 , 로 연결하여 출력하기

# %%
#더하기로 +로 연결하여 출력하기

# %% [markdown]
# # 3. 입력명령어
# ### 입력명령어 형식
#
# > input('입력안내문')
# ######입력한 단어가 결과창에 뜸

# %%
#소괄호의 내용은 입력할 내용의 안내문 역할

# %% [markdown]
# ##### 실습1. 웹사이트 회원가입 시스템 만들어보기
