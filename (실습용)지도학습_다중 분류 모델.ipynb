# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/python/blob/main/(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%EC%A7%80%EB%8F%84%ED%95%99%EC%8A%B5_%EB%8B%A4%EC%A4%91%20%EB%B6%84%EB%A5%98%20%EB%AA%A8%EB%8D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 붓꽃 데이터를 분류해보자!
# ![image.png](data:image/png;base64,...)

# %%
# 한글 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 2s (5,574 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %% [markdown]
# # 필요한 모듈 포함시키기
#
# 1.붓꽃 데이터를 데이터 프레임으로 불러오기 위한 모듈
# *   pandas : 데이터 분석 기능을 제공하는 모듈
#
# 3. 특징들 간의 상관관계를 그래프를 그리기 위해 필요한 seaborn 모듈 포함시키기
# *   seaborn : 데이터 시각화 기능을 제공하는 라이브러리, 다양한 그래프를 생성하는 모듈
#
# 5. 한글 폰트 지정을 위해 필요한 모듈 포함시켜서 fm으로 지정하기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %% [markdown]
# ## 데이터 세트 불러오기

# %% [markdown]
# # 한글폰트 설정하기

# %% [markdown]
# # 데이터 특징들 간의 상관 관계를 처리하고 data_f에 저장하기
# *    '피어슨의 상관 계수' 를 통해 iris_data 데이터의 특징들 간 상관관계를 구하고 data_f에 저장
# * 피어슨(pearson) 상관 계수 : 두 변수 간의 관련성을 구하기 위해 상관 관계 분석에 보편적으로 이용 범위는 -1<=피어슨<=1 이며, 1과 가까울수록 관련성이 높고 -1과 가까울수록 관련성이 낮다

# %% [markdown]
# ## 출력될 그래프의 크기 지정하기

# %% [markdown]
# #히트맵
# > 두 변수간의 상관관계를 컬러로 변환시켜 열 분포 형태로 시각적인 분석을 가능하게 함

# %% [markdown]
# # 데이터 특징들 간의 피어슨 상관관계를 그래프로 보여주는 코드(히트맵) 입력하기
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 붉은 색일수록 필요한 데이터 속성이다.
# ###### 히트맵의 상관도를 보고 붓꽃의 종을 분류하기 위해 필요한 데이터 속성과 불필요한 데이터 속성을 구분해보자!

# %% [markdown]
# # 4가지 데이터로 붓꽃의 종류를 분류할 수 있는지 확인 가능한 그래프를 출력하는 코드

# %% [markdown]
# #예측에 필요한 모듈 포함 시키기

# %% [markdown]
# >사이킷런에서 제공해주는 예제 데이터 불러오기

# %% [markdown]
# 붓꽃 데이터 불러오기

# %% [markdown]
# 훈련 데이터와 테스트 데이터를 저장

# %% [markdown]
# 학습 모델 선언 및 학습

# %% [markdown]
# #학습된 모델로 테스트 데이터 예측
# ##### [0] -> 세토사, [1] -> 버시컬러, [2] -> 버지니카

# %% [markdown]
# 새로운 데이터로 예측해보기
