# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/python/blob/main/(%EC%8B%A4%EC%8A%B5%EC%9A%A9)_%ED%8C%8C%EC%9D%B4%EC%8D%AC_2%EC%9D%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. 변수
# > 변수이름 = 저장할 데이터
#
# ![캡처.JPG](data:image/jpeg;base64,...)

# %%
# 변수이름 a, 안녕 넣어보기

# %%
# 변수b에다가 56 넣어보기

# %% [markdown]
# ### 변수를 활용하여 연산하기
# ######- 과일 가격 계산하기

# %%
# 사과 3개, 바나나1개, 키위2개 구매한 가격은?

# %%
# price라는 변수에 넣고 출력하기

# %% [markdown]
# ######vip는 20% 할인된다. 동일한 물건을 구매했을 때 vip가 내는 가격을 새로운 변수에 저장하여 출력하기

# %%
#vip가 되시면 ~원을 ~원에 구매 가능합니다.

# %% [markdown]
# >입력받아 저장하기

# %% [markdown]
# ###### 실습1. 회원가입 사이트
# ###### 입력받고 입력받은 아이디로 "00님 웹사이트 가입을 환영합니다~" 라고 출력하기!

# %% [markdown]
# #2. 변수와 입력
# ### 입력받을 때는 항상 문자로 입력됨.
# >데이터타입
# ###### 1) 정수 int
# ###### 2) 실수 float
# ###### 3) 문자 str

# %%
# 정수를 실수로

# %%
# 실수를 정수로

# %% [markdown]
# ###### 실습2. 원의 둘레, 넓이, 구의 겉넓이, 부피 구하기
# ###### 반지름 입력받아서, 입력받은 반지름을 갖는 원의 둘레, 넓이, 구 겉넓이, 부피를 출력하기!

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %%
# 원의 둘레


# 원의 넓이


# 구의 겉넓이


# 구의 부피

# %%
#반지름 입력

# 원의 둘레


# 원의 넓이


# 구의 겉넓이


# 구의 부피
